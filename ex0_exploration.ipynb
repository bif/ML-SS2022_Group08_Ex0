# %% [markdown]
# # <h1 style="text-align: center"><b>184.702 Machine Learning</b>: Exercise 0, 2022S</h1>
# <h5 style="text-align: center">Group 08: Wanecek Wilhelm, Simhandl Stefan, Beck Viktor</h5>

# %%
# Install dependencies
# !pip3 install -q pandas_profiling

# %%
import os
path= ''
currentdirectory = os.path.abspath(path)
os.chdir(currentdirectory)

import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from pandas_profiling import ProfileReport

# %% [markdown]
# # Kinematics-motion-dataset
#
# source:
# https://www.kaggle.com/yasserh/kinematics-motion-data

# %%
# import raw data
csvpath = os.path.join("datasets", "kinematics-motion-data.csv")
kinematics_df = pd.read_csv(csvpath, sep=',', encoding='latin-1')
display(kinematics_df.info())
display(kinematics_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88588 entries, 0 to 88587
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            88588 non-null  object
#  1   time            88588 non-null  object
#  2   username        88588 non-null  object
#  3   wrist           88588 non-null  int64
#  4   activity        88588 non-null  int64
#  5   acceleration_x  88588 non-null  float64
#  6   acceleration_y  88588 non-null  float64
#  7   acceleration_z  88588 non-null  float64
#  8   gyro_x          88588 non-null  float64
#  9   gyro_y          88588 non-null  float64
#  10  gyro_z          88588 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 7.4+ MB
# None
#         date                time username  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020   viktor      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023   viktor      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987   viktor      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985   viktor      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994   viktor      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922

# %% [markdown]
# ## Explore kinematics-motion-dataset

# %%
print("Shape of dataset (row, columns):", kinematics_df.shape)
print('Missing values:\n', kinematics_df.isna().sum())
# Out:
# Shape of dataset (row, columns): (88588, 11)
# Missing values:
#  date              0
# time              0
# username          0
# wrist             0
# activity          0
# acceleration_x    0
# acceleration_y    0
# acceleration_z    0
# gyro_x            0
# gyro_y            0
# gyro_z            0
# dtype: int64

# %%
# Get descriptive statistical properties of dataset
kinematics_df.describe()
# Out:
#               wrist      activity  acceleration_x  acceleration_y  \
# count  88588.000000  88588.000000    88588.000000    88588.000000
# mean       0.522170      0.500801       -0.074811       -0.562585
# std        0.499511      0.500002        1.009299        0.658458
# min        0.000000      0.000000       -5.350500       -3.299000
# 25%        0.000000      0.000000       -0.381800       -1.033500
# 50%        1.000000      1.000000       -0.059500       -0.759100
# 75%        1.000000      1.000000        0.355500       -0.241775
# max        1.000000      1.000000        5.603300        2.668000
#
#        acceleration_z        gyro_x        gyro_y        gyro_z
# count    88588.000000  88588.000000  88588.000000  88588.000000
# mean        -0.313956      0.004160      0.037203      0.022327
# std          0.486815      1.253423      1.198725      1.914423
# min         -3.753800     -4.430600     -7.464700     -9.480000
# 25%         -0.376000     -0.920700     -0.644825     -1.345125
# 50%         -0.221000      0.018700      0.039300      0.006900
# 75%         -0.085900      0.888800      0.733700      1.398200
# max          1.640300      4.874200      8.498000     11.266200

# %%
# 1) Date, Time and Username are no universal features to predict the activites Running and Walking 
# 2) Further it makes no sense to explore them so we can drop them before exploring the data
kinematics_df = kinematics_df.drop(columns=['username','date','time'],axis=1)

# Explore dataset using pandas profiling
kinematics_df = ProfileReport(kinematics_df, minimal = False)
report_path = os.path.join('reports', 'explore_kinematics-motion-dataset.html')
kinematics_df.to_file(output_file=report_path)
# Out:
# Summarize dataset: 100%|██████████| 57/57 [00:07<00:00,  7.71it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:01<00:00,  1.72s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 137.18it/s]

# %% [markdown]
# # Communities and Crime dataset
#
# source:
# https://archive.ics.uci.edu/ml/datasets/Communities+and+Crime

# %%
# import raw data
csvpath = os.path.join("datasets", "communities_crime.csv")
cc_df_raw = pd.read_csv(csvpath, sep=';', encoding='latin-1')

display(cc_df_raw.info())
display(cc_df_raw.head(2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Columns: 128 entries, state: US state (by number) - not counted as predictive above, but if considered, should be consided nominal (nominal) to ViolentCrimesPerPop: total number of violent crimes per 100K popuation (numeric - decimal) GOAL attribute (to be predicted)
# dtypes: float64(125), int64(2), object(1)
# memory usage: 1.9+ MB
# None
#    state: US state (by number) - not counted as predictive above, but if considered, should be consided nominal (nominal)  \
# 0                                                  8
# 1                                                 53
#
#    county: numeric code for county - not predictive, and many missing values (numeric)  \
# 0                                                NaN
# 1                                                NaN
#
#    community: numeric code for community - not predictive and many missing values (numeric)  \
# 0                                                NaN
# 1                                                NaN
#
#   communityname: community name - not predictive - for information only (string)  \
# 0                                       Lakewoodcity
# 1                                        Tukwilacity
#
#    fold: fold number for non-random 10 fold cross validation, potentially useful for debugging, paired tests - not predictive (numeric)  \
# 0                                                  1
# 1                                                  1
#
#    population: population for community: (numeric - decimal)  \
# 0                                               0.19
# 1                                               0.00
#
#    householdsize: mean people per household (numeric - decimal)  \
# 0                                               0.33
# 1                                               0.16
#
#    racepctblack: percentage of population that is african american (numeric - decimal)  \
# 0                                               0.02
# 1                                               0.12
#
#    racePctWhite: percentage of population that is caucasian (numeric - decimal)  \
# 0                                               0.90
# 1                                               0.74
#
#    racePctAsian: percentage of population that is of asian heritage (numeric - decimal)  \
# 0                                               0.12
# 1                                               0.45
#
#    ...  LandArea: land area in square miles (numeric - decimal)  \
# 0  ...                                               0.12
# 1  ...                                               0.02
#
#    PopDens: population density in persons per square mile (numeric - decimal)  \
# 0                                               0.26
# 1                                               0.12
#
#    PctUsePubTrans: percent of people using public transit for commuting (numeric - decimal)  \
# 0                                               0.20
# 1                                               0.45
#
#    PolicCars: number of police cars (numeric - decimal)  \
# 0                                               0.06
# 1                                                NaN
#
#    PolicOperBudg: police operating budget (numeric - decimal)  \
# 0                                               0.04
# 1                                                NaN
#
#    LemasPctPolicOnPatr: percent of sworn full time police officers on patrol (numeric - decimal)  \
# 0                                                0.9
# 1                                                NaN
#
#    LemasGangUnitDeploy: gang unit deployed (numeric - decimal - but really ordinal - 0 means NO, 1 means YES, 0.5 means Part Time)  \
# 0                                                0.5
# 1                                                NaN
#
#    LemasPctOfficDrugUn: percent of officers assigned to drug units (numeric - decimal)  \
# 0                                               0.32
# 1                                               0.00
#
#    PolicBudgPerPop: police operating budget per population (numeric - decimal)  \
# 0                                               0.14
# 1                                                NaN
#
#    ViolentCrimesPerPop: total number of violent crimes per 100K popuation (numeric - decimal) GOAL attribute (to be predicted)
# 0                                               0.20
# 1                                               0.67
#
# [2 rows x 128 columns]

# %%
# get US state postcode mapping from https://github.com/scpike/us-state-county-zip/blob/master/geo-data.csv
csvpath = os.path.join("datasets", 'US_state-fips.csv')
state_fips = pd.read_csv(csvpath, sep=',', encoding='latin-1')

display(state_fips.head(1))
state_fips = state_fips.drop(state_fips.columns[2:6],axis=1)
display(state_fips.head(1))
# Out:
#    state_fips    state state_abbr zipcode     county   city
# 0           1  Alabama         AL   35004  St. Clair  Acmar
#    state_fips    state
# 0           1  Alabama

# %% [markdown]
# ## Explore communities and crime dataset

# %%
print("Shape of raw dataset (row, columns):", cc_df_raw.shape)
#print('Missing values:\n', cc_df.isna().sum()) # better overview by Pandas Profiling report
# Out:
# Shape of dataset (row, columns): (1994, 128)

# %%
# How many columns are non-predictive?
def listNonPredictiveCols(df: pd.DataFrame) -> int:
    nonPredictiveCols = df.columns[df.columns.str.contains('predictive')]
    return nonPredictiveCols

cc_nonPredictiveCols = listNonPredictiveCols(cc_df_raw)
display(len(cc_nonPredictiveCols), cc_nonPredictiveCols)
# Out:
# 5
# Index(['state: US state (by number) - not counted as predictive above, but if considered, should be consided nominal (nominal)',
#        'county: numeric code for county - not predictive, and many missing values (numeric)',
#        'community: numeric code for community - not predictive and many missing values (numeric)',
#        'communityname: community name - not predictive - for information only (string)',
#        'fold: fold number for non-random 10 fold cross validation, potentially useful for debugging, paired tests - not predictive (numeric)'],
#       dtype='object')

# %%
## drop non predicitve features
# 1) state, fold, county, community and communityname are no universal features to predict the crime rate (state and community name kept as indexes for additional information might be dropted for ML)
# 2) Further it makes no sense to explore them so we can drop them before exploring the data
cc_df = cc_df_raw.copy().rename(columns={'state: US state (by number) - not counted as predictive above, but if considered, should be consided nominal (nominal)': 'state_fips',
                                  'communityname: community name - not predictive - for information only (string)': 'communityname'})

cc_df = cc_df.drop(columns=['fold: fold number for non-random 10 fold cross validation, potentially useful for debugging, paired tests - not predictive (numeric)',
                      'county: numeric code for county - not predictive, and many missing values (numeric)',
                      'community: numeric code for community - not predictive and many missing values (numeric)'],axis=1)

cc_df = pd.concat([cc_df, state_fips], axis=1, join="inner").drop(columns='state_fips')
cc_df = cc_df.set_index(['state','communityname'])
display(cc_df.head(3))

# Get shape of pre-processed datase 
print("Shape of pre-processed dataset (row, columns):", cc_df.shape)

# Get descriptive statistical properties of dataset
cc_df.describe()

# Explore dataset using pandas profiling (ignore indexes by dropping them from input). Since this df is so big, we only output a minimal report.
df_rep = cc_df.copy().droplevel(level=0).reset_index(drop=True)
cc_prof = ProfileReport(df_rep, minimal = True)
report_path = os.path.join('reports', 'explore_communities-crime-dataset.html')
cc_prof.to_file(output_file=report_path)
# Out:
#                        population: population for community: (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.19
#         Tukwilacity                                                 0.00
#         Aberdeentown                                                0.00
#
#                        householdsize: mean people per household (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.33
#         Tukwilacity                                                 0.16
#         Aberdeentown                                                0.42
#
#                        racepctblack: percentage of population that is african american (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.02
#         Tukwilacity                                                 0.12
#         Aberdeentown                                                0.49
#
#                        racePctWhite: percentage of population that is caucasian (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.90
#         Tukwilacity                                                 0.74
#         Aberdeentown                                                0.56
#
#                        racePctAsian: percentage of population that is of asian heritage (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.12
#         Tukwilacity                                                 0.45
#         Aberdeentown                                                0.17
#
#                        racePctHisp: percentage of population that is of hispanic heritage (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.17
#         Tukwilacity                                                 0.07
#         Aberdeentown                                                0.04
#
#                        agePct12t21: percentage of population that is 12-21 in age (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.34
#         Tukwilacity                                                 0.26
#         Aberdeentown                                                0.39
#
#                        agePct12t29: percentage of population that is 12-29 in age (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.47
#         Tukwilacity                                                 0.59
#         Aberdeentown                                                0.47
#
#                        agePct16t24: percentage of population that is 16-24 in age (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.29
#         Tukwilacity                                                 0.35
#         Aberdeentown                                                0.28
#
#                        agePct65up: percentage of population that is 65 and over in age (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.32
#         Tukwilacity                                                 0.27
#         Aberdeentown                                                0.32
#
#                        ...  \
# state   communityname  ...
# Alabama Lakewoodcity   ...
#         Tukwilacity    ...
#         Aberdeentown   ...
#
#                        LandArea: land area in square miles (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.12
#         Tukwilacity                                                 0.02
#         Aberdeentown                                                0.01
#
#                        PopDens: population density in persons per square mile (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.26
#         Tukwilacity                                                 0.12
#         Aberdeentown                                                0.21
#
#                        PctUsePubTrans: percent of people using public transit for commuting (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.20
#         Tukwilacity                                                 0.45
#         Aberdeentown                                                0.02
#
#                        PolicCars: number of police cars (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.06
#         Tukwilacity                                                  NaN
#         Aberdeentown                                                 NaN
#
#                        PolicOperBudg: police operating budget (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.04
#         Tukwilacity                                                  NaN
#         Aberdeentown                                                 NaN
#
#                        LemasPctPolicOnPatr: percent of sworn full time police officers on patrol (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                 0.9
#         Tukwilacity                                                  NaN
#         Aberdeentown                                                 NaN
#
#                        LemasGangUnitDeploy: gang unit deployed (numeric - decimal - but really ordinal - 0 means NO, 1 means YES, 0.5 means Part Time)  \
# state   communityname
# Alabama Lakewoodcity                                                 0.5
#         Tukwilacity                                                  NaN
#         Aberdeentown                                                 NaN
#
#                        LemasPctOfficDrugUn: percent of officers assigned to drug units (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.32
#         Tukwilacity                                                 0.00
#         Aberdeentown                                                0.00
#
#                        PolicBudgPerPop: police operating budget per population (numeric - decimal)  \
# state   communityname
# Alabama Lakewoodcity                                                0.14
#         Tukwilacity                                                  NaN
#         Aberdeentown                                                 NaN
#
#                        ViolentCrimesPerPop: total number of violent crimes per 100K popuation (numeric - decimal) GOAL attribute (to be predicted)
# state   communityname
# Alabama Lakewoodcity                                                0.20
#         Tukwilacity                                                 0.67
#         Aberdeentown                                                0.43
#
# [3 rows x 123 columns]
# Shape of pre-processed dataset (row, columns): (1994, 123)
# Summarize dataset: 100%|██████████| 129/129 [00:00<00:00, 201.67it/s, Completed]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# compute nbr of attributes with ratio respective interval data
cols = list(cc_df.columns.values)
nbr_ratio = pd.Series(cols).str.count('[P,p]ct').sum()
print('Number of attributes with ratio data :', nbr_ratio)
print('Number of attributes with interval data:', len(cols)-nbr_ratio)
# Out:
# Number of attributes with ratio data : 73
# Number of attributes with interval data: 50
